# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('file4.csv')
df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ... number_of_policies  \
# 0        2011-02-18         Employed      M   48029  ...                  9
# 1        2011-01-18       Unemployed      F       0  ...                  1
# 2        2011-02-10         Employed      M   22139  ...                  2
# 3        2011-01-11         Employed      M   49078  ...                  2
# 4        2011-01-17    Medical Leave      F   23675  ...                  7
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
# 1   Personal Auto   Personal L3            Offer4    Call Center
# 2   Personal Auto   Personal L3            Offer3    Call Center
# 3  Corporate Auto  Corporate L3            Offer2         Branch
# 4   Personal Auto   Personal L2            Offer1         Branch
#
#    total_claim_amount  vehicle_class vehicle_size vehicle_type month
# 0          292.800000  Four-Door Car      Medsize            A     2
# 1          744.924331  Four-Door Car      Medsize            A     1
# 2          480.000000            SUV      Medsize            A     2
# 3          484.013411  Four-Door Car      Medsize            A     1
# 4          707.925645  Four-Door Car      Medsize            A     1
#
# [5 rows x 26 columns]

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
filtered_df = df[(df['total_claim_amount'] > 1000) & (df['response'] == 'Yes')]

print("Filtered DataFrame:")
display(filtered_df)
# Out:
# Filtered DataFrame:
#       customer       state  customer_lifetime_value response  coverage  \
# 189    OK31456  California             11009.130490      Yes   Premium
# 236    YJ16163      Oregon             11009.130490      Yes   Premium
# 419    GW43195      Oregon             25807.063000      Yes  Extended
# 442    IP94270     Arizona             13736.132500      Yes   Premium
# 587    FJ28407  California              5619.689084      Yes   Premium
# ...        ...         ...                      ...      ...       ...
# 10351  FN44127      Oregon              3508.569533      Yes  Extended
# 10373  XZ64172      Oregon             10963.957230      Yes   Premium
# 10487  IX60941      Oregon              3508.569533      Yes  Extended
# 10565  QO62792      Oregon              7840.165778      Yes  Extended
# 10708  CK39096      Oregon              5619.689084      Yes   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 189                Bachelor        2011-01-24         Employed      F   51643
# 236                Bachelor        2011-01-24         Employed      F   51643
# 419                 College        2011-02-13         Employed      F   71210
# 442                  Master        2011-02-13         Disabled      F   16181
# 587    High School or Below        2011-01-26       Unemployed      M       0
# ...                     ...               ...              ...    ...     ...
# 10351               College        2011-01-05    Medical Leave      M   20978
# 10373  High School or Below        2011-02-08         Employed      M   55687
# 10487               College        2011-01-05    Medical Leave      M   20978
# 10565               College        2011-01-14         Employed      M   58414
# 10708  High School or Below        2011-01-26       Unemployed      M       0
#
#        ... number_of_policies     policy_type        policy  renew_offer_type  \
# 189    ...                  1  Corporate Auto  Corporate L3            Offer2
# 236    ...                  1    Special Auto    Special L3            Offer2
# 419    ...                  2   Personal Auto   Personal L2            Offer1
# 442    ...                  8   Personal Auto   Personal L2            Offer1
# 587    ...                  1   Personal Auto   Personal L1            Offer2
# ...    ...                ...             ...           ...               ...
# 10351  ...                  1   Personal Auto   Personal L2            Offer2
# 10373  ...                  1  Corporate Auto  Corporate L2            Offer1
# 10487  ...                  1   Personal Auto   Personal L3            Offer2
# 10565  ...                  1   Personal Auto   Personal L3            Offer2
# 10708  ...                  1   Personal Auto   Personal L3            Offer2
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 189            Agent         1358.400000     Luxury Car      Medsize
# 236            Agent         1358.400000     Luxury Car      Medsize
# 419           Branch         1027.200000     Luxury Car        Small
# 442              Web         1261.319869            SUV      Medsize
# 587              Web         1027.000029            SUV      Medsize
# ...              ...                 ...            ...          ...
# 10351         Branch         1176.278800  Four-Door Car        Small
# 10373          Agent         1324.800000     Luxury SUV      Medsize
# 10487         Branch         1176.278800  Four-Door Car        Small
# 10565          Agent         1008.000000  Four-Door Car      Medsize
# 10708            Web         1027.000029            SUV      Medsize
#
#       vehicle_type month
# 189              A     1
# 236              A     1
# 419              A     2
# 442              A     2
# 587              A     1
# ...            ...   ...
# 10351            A     1
# 10373            A     2
# 10487            A     1
# 10565            A     1
# 10708            A     1
#
# [67 rows x 26 columns]

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
filtered_df = df[df['response'] == 'Yes']
grouped_df = filtered_df.groupby(['policy_type','gender']).agg({'total_claim_amount':'mean'}).reset_index()
grouped_df = grouped_df.rename(columns = {'total_claim_amount':'average_total_claim_amount'})
display(grouped_df)
# Out:
#       policy_type gender  average_total_claim_amount
# 0  Corporate Auto      F                  433.738499
# 1  Corporate Auto      M                  408.582459
# 2   Personal Auto      F                  452.965929
# 3   Personal Auto      M                  457.010178
# 4    Special Auto      F                  453.280164
# 5    Special Auto      M                  429.527942

# %% [markdown]
# The difference between the mean values of total claim amounts across the data subset is insignificant, which makes it difficult to assume correlation between policy type and gender

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
# Get the unique values of 'state'
unique_states = df['state'].nunique()
print(unique_states)
# Out:
# 5

# %%
filtered_customers = df[df['number_of_policies'] >= 5]

# Step 2: Count the number of customers for each state
customer_counts_by_state = filtered_customers['state'].value_counts()

# Step 3: Filter states where there are more than 500 customers
states_with_more_than_500_customers = customer_counts_by_state[customer_counts_by_state > 500].index

# Step 4: Filter the original DataFrame based on the selected states
final_result = filtered_customers[filtered_customers['state'].isin(states_with_more_than_500_customers)]

display(final_result)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 4      QA50777      Oregon              9025.067525       No   Premium
# 5      HO81102  California              4745.181764       No     Basic
# 16     FH51383  California              5326.677654       No     Basic
# 20     OM80593  California              7247.313475       No     Basic
# 22     EQ62488      Oregon             15031.564500       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10895  EG40670  California              6232.687923       No  Extended
# 10898  SO95845  California              5807.659307       No     Basic
# 10899  WU60905  California              8610.667489       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# 4                  Bachelor        2011-01-17    Medical Leave      F   23675
# 5      High School or Below        2011-02-14         Employed      M   50549
# 16     High School or Below        2011-02-07         Employed      F   76717
# 20                 Bachelor        2011-02-23       Unemployed      F       0
# 22                  College        2011-01-15         Employed      F   59456
# ...                     ...               ...              ...    ...     ...
# 10895              Bachelor        2011-01-08         Disabled      F   28334
# 10898               College        2011-01-07         Employed      F   62447
# 10899  High School or Below        2011-02-06       Unemployed      F       0
# 10906               College        2011-01-06         Employed      F   61146
# 10908               College        2011-02-13         Employed      F   64195
#
#        ... number_of_policies     policy_type        policy  renew_offer_type  \
# 4      ...                  7   Personal Auto   Personal L2            Offer1
# 5      ...                  7   Personal Auto   Personal L3            Offer1
# 16     ...                  6   Personal Auto   Personal L3            Offer4
# 20     ...                  7   Personal Auto   Personal L3            Offer1
# 22     ...                  8   Personal Auto   Personal L3            Offer2
# ...    ...                ...             ...           ...               ...
# 10895  ...                  7    Special Auto    Special L3            Offer1
# 10898  ...                  7   Personal Auto   Personal L3            Offer4
# 10899  ...                  9  Corporate Auto  Corporate L1            Offer3
# 10906  ...                  6   Personal Auto   Personal L3            Offer2
# 10908  ...                  6   Personal Auto   Personal L1            Offer1
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 4             Branch          707.925645  Four-Door Car      Medsize
# 5              Agent          292.800000  Four-Door Car      Medsize
# 16       Call Center          300.528579   Two-Door Car        Large
# 20       Call Center          499.200000            SUV      Medsize
# 22       Call Center          907.200000     Luxury Car        Large
# ...              ...                 ...            ...          ...
# 10895          Agent          537.765151  Four-Door Car      Medsize
# 10898    Call Center          133.977857   Two-Door Car      Medsize
# 10899            Web          532.800000            SUV      Medsize
# 10906         Branch          273.018929  Four-Door Car      Medsize
# 10908         Branch          618.288849            SUV      Medsize
#
#       vehicle_type month
# 4                A     1
# 5                A     2
# 16               A     2
# 20               A     2
# 22               A     1
# ...            ...   ...
# 10895            A     1
# 10898            A     1
# 10899            A     2
# 10906            A     1
# 10908            A     2
#
# [1582 rows x 26 columns]

# %%
filtered_customers = df.groupby('customer')['state'].nunique()
filtered_customers = filtered_customers[filtered_customers == len(unique_states)].index

# Filter the original DataFrame based on the selected customers
result_df = df[df['customer'].isin(filtered_customers)]

print(result_df)
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type, month]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Second solution of 3.

# %%
customer_counts = df['customer'].value_counts()

# Filter customers with counts greater than or equal to 5
filtered_customers = customer_counts[customer_counts >= 5].index

# Filter the original DataFrame based on the selected customers
result_df = df[df['customer'].isin(filtered_customers)]
result_df = result_df.sort_values(by='customer', ascending=False)
display(result_df)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 691    ID89933      Oregon              7255.577594       No  Extended
# 4996   ID89933      Oregon              7255.577594       No  Extended
# 6743   ID89933  California              7255.577594       No  Extended
# 6091   ID89933      Oregon              7255.577594       No  Extended
# 3389   ID89933  California              7255.577594       No  Extended
# 4581   ID89933      Oregon              7255.577594       No  Extended
# 950    ID89933      Oregon              7255.577594       No  Extended
# 9943   FP86246  California             13211.010920       No   Premium
# 7539   FP86246  California             13211.010920       No   Premium
# 10384  FP86246  California             13211.010920       No   Premium
# 2867   FP86246  California             13211.010920       No   Premium
# 1882   FP86246  California             13211.010920       No   Premium
# 4995   DQ50258  California              4814.350556       No     Basic
# 6448   DQ50258  California              4814.350556       No     Basic
# 8310   DQ50258  California              4814.350556       No     Basic
# 10105  DQ50258  California              4814.350556       No     Basic
# 5421   DQ50258  California              4814.350556       No     Basic
# 5360   AM79057      Oregon              2287.917290       No     Basic
# 3062   AM79057  California              2287.917290       No     Basic
# 6117   AM79057  California              2287.917290       No     Basic
# 6692   AM79057      Oregon              2287.917290       No     Basic
# 2642   AM79057  California              2287.917290       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# 691      Doctor        2011-01-09         Employed      F   39786  ...
# 4996     Doctor        2011-01-09         Employed      F   39786  ...
# 6743     Doctor        2011-01-09         Employed      F   39786  ...
# 6091     Doctor        2011-01-09         Employed      F   39786  ...
# 3389     Doctor        2011-01-09         Employed      F   39786  ...
# 4581     Doctor        2011-01-09         Employed      F   39786  ...
# 950      Doctor        2011-01-09         Employed      F   39786  ...
# 9943   Bachelor        2011-01-31         Employed      M   74656  ...
# 7539   Bachelor        2011-01-31         Employed      M   74656  ...
# 10384  Bachelor        2011-01-31         Employed      M   74656  ...
# 2867   Bachelor        2011-01-31         Employed      M   74656  ...
# 1882   Bachelor        2011-01-31         Employed      M   74656  ...
# 4995    College        2011-02-07       Unemployed      M       0  ...
# 6448    College        2011-02-07       Unemployed      M       0  ...
# 8310    College        2011-02-07       Unemployed      M       0  ...
# 10105   College        2011-02-07       Unemployed      M       0  ...
# 5421    College        2011-02-07       Unemployed      M       0  ...
# 5360   Bachelor        2011-02-18         Employed      F   69024  ...
# 3062   Bachelor        2011-02-18         Employed      F   69024  ...
# 6117   Bachelor        2011-02-18         Employed      F   69024  ...
# 6692   Bachelor        2011-02-18         Employed      F   69024  ...
# 2642   Bachelor        2011-02-18         Employed      F   69024  ...
#
#       number_of_policies    policy_type       policy  renew_offer_type  \
# 691                    9  Personal Auto  Personal L2            Offer1
# 4996                   9  Personal Auto  Personal L2            Offer1
# 6743                   9  Personal Auto  Personal L2            Offer1
# 6091                   9  Personal Auto  Personal L2            Offer1
# 3389                   9  Personal Auto  Personal L2            Offer1
# 4581                   9  Personal Auto  Personal L2            Offer1
# 950                    9  Personal Auto  Personal L2            Offer1
# 9943                   2  Personal Auto  Personal L2            Offer3
# 7539                   2  Personal Auto  Personal L2            Offer3
# 10384                  2  Personal Auto  Personal L2            Offer3
# 2867                   2  Personal Auto  Personal L2            Offer3
# 1882                   2  Personal Auto  Personal L2            Offer3
# 4995                   4  Personal Auto  Personal L3            Offer2
# 6448                   4  Personal Auto  Personal L3            Offer2
# 8310                   4  Personal Auto  Personal L3            Offer2
# 10105                  4  Personal Auto  Personal L3            Offer2
# 5421                   4  Personal Auto  Personal L3            Offer2
# 5360                   1  Personal Auto  Personal L2            Offer2
# 3062                   1  Personal Auto  Personal L2            Offer2
# 6117                   1  Personal Auto  Personal L2            Offer2
# 6692                   1  Personal Auto  Personal L2            Offer2
# 2642                   1  Personal Auto  Personal L2            Offer2
#
#        sales_channel  total_claim_amount  vehicle_class vehicle_size  \
# 691              Web          365.835977  Four-Door Car      Medsize
# 4996             Web          365.835977  Four-Door Car      Medsize
# 6743             Web          365.835977  Four-Door Car      Medsize
# 6091             Web          365.835977  Four-Door Car      Medsize
# 3389             Web          365.835977  Four-Door Car      Medsize
# 4581             Web          365.835977  Four-Door Car      Medsize
# 950              Web          365.835977  Four-Door Car      Medsize
# 9943     Call Center          504.365927  Four-Door Car      Medsize
# 7539     Call Center          504.365927  Four-Door Car      Medsize
# 10384    Call Center          504.365927  Four-Door Car      Medsize
# 2867     Call Center          504.365927  Four-Door Car      Medsize
# 1882     Call Center          504.365927  Four-Door Car      Medsize
# 4995           Agent          482.400000  Four-Door Car      Medsize
# 6448           Agent          482.400000  Four-Door Car      Medsize
# 8310           Agent          482.400000  Four-Door Car      Medsize
# 10105          Agent          482.400000  Four-Door Car      Medsize
# 5421           Agent          482.400000  Four-Door Car      Medsize
# 5360             Web          238.530745  Four-Door Car      Medsize
# 3062             Web          238.530745  Four-Door Car      Medsize
# 6117             Web          238.530745  Four-Door Car      Medsize
# 6692             Web          238.530745  Four-Door Car      Medsize
# 2642             Web          238.530745  Four-Door Car      Medsize
#
#       vehicle_type month
# 691              A     1
# 4996             A     1
# 6743             A     1
# 6091             A     1
# 3389             A     1
# 4581             A     1
# 950              A     1
# 9943             A     1
# 7539             A     1
# 10384            A     1
# 2867             A     1
# 1882             A     1
# 4995             A     2
# 6448             A     2
# 8310             A     2
# 10105            A     2
# 5421             A     2
# 5360             A     2
# 3062             A     2
# 6117             A     2
# 6692             A     2
# 2642             A     2
#
# [22 rows x 26 columns]

# %% [markdown]
# There are no customers who have policies in each state

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
result_df = df.groupby(['education', 'gender'])['customer_lifetime_value'].agg(['max', 'min', 'median']).reset_index()

display(result_df)
# Out:
#               education gender          max          min       median
# 0              Bachelor      F  73225.95652  1904.000852  5640.505303
# 1              Bachelor      M  67907.27050  1898.007675  5548.031892
# 2               College      F  61850.18803  1898.683686  5623.611187
# 3               College      M  61134.68307  1918.119700  6005.847375
# 4                Doctor      F  44856.11397  2395.570000  5332.462694
# 5                Doctor      M  32677.34284  2267.604038  5577.669457
# 6  High School or Below      F  55277.44589  2144.921535  6039.553187
# 7  High School or Below      M  83325.38119  1940.981221  6286.731006
# 8                Master      F  51016.06704  2417.777032  5729.855012
# 9                Master      M  50568.25912  2272.307310  5579.099207

# %% [markdown]
# Across all education levels, females generally have higher maximum customer lifetime values compared to males.
#  However, the minimum and median values do not consistently follow this pattern, indicating variability in customer lifetime values.
#     The highest maximum customer lifetime values are generally associated with the "Bachelor" and "College" education levels for both gend
#     The "High School or Below" education level exhibits the highest maximum value for males, but not for fem.
#     Customer lifetime values tend to vary across different educational levels, suggesting a potential correlation between education and spending behes:
#
#     The range between the maximum and minimum values is substantial for each category, indicating a diverse range of customer behaviors and values within egroup.
#     The range is particularly wide for the "High School or Below" education level, especiall  This can indicate the possibility of outliers or extreme values affecting the overall statistics.y Values:
#
#     The median values provide insights into the central tendency of customer lifetime values witeach group.
#     For some groups, such as females with a "Doctor" degree, the median is relatively lower compared to the maximum value, indicating potential outliers or skewel Influence:
#
#     Customer lifetime values do not strictly follow a linear pattern with education level. For instance, while "Doctor" level customers generally have lower maximum values, they might have higher median values compared to otg the overall statistics.

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %%
policies_by_state_and_month = df.pivot_table(values='number_of_policies', index='state', columns='month', aggfunc='sum', fill_value=0)

display(policies_by_state_and_month)
# Out:
# month          1     2
# state
# Arizona     3052  2864
# California  6666  5901
# Nevada      1493  1278
# Oregon      4697  3969
# Washington  1358  1225

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %%
grouped_data = df.groupby(['state', 'month'])['number_of_policies'].count().reset_index()
sorted_data = grouped_data.sort_values(by='number_of_policies', ascending=False)

# Select the top 3 states with the highest number of policies sold
top_states = sorted_data['state'].unique()[:3]

# Create a new DataFrame for the top 3 states
top_states_df = grouped_data[grouped_data['state'].isin(top_states)]

display(top_states_df)
# Out:
#         state  month  number_of_policies
# 0     Arizona      1                1008
# 1     Arizona      2                 929
# 2  California      1                2231
# 3  California      2                1952
# 6      Oregon      1                1565
# 7      Oregon      2                1344

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
#unpivot the data using melt
melted_df = pd.melt(df, id_vars=['sales_channel'], value_vars=['response'])

#filter the data for 'response' equal to 'Yes'
filtered_df = melted_df[melted_df['value'] == 'Yes']

#calculate response rate using pivot_table
response_rate_table = pd.pivot_table(filtered_df, index='sales_channel', values='value', aggfunc='count', fill_value=0).reset_index()

#rename the column to 'response_rate'
response_rate_table = response_rate_table.rename(columns={'value': 'response_yes'})

display(response_rate_table)
# Out:
#   sales_channel  response_yes
# 0         Agent           742
# 1        Branch           326
# 2   Call Center           221
# 3           Web           177
